# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

#load data set
chilla = pd.read_csv("faostat.csv")
#print(chilla)

#figure size
#plt.figure(figsize=(1,1))

#draw a bar plot
# order of data 
# ci graph se dande hatane k lye
#
sns.barplot(x="Year",y="Value",hue="Element",data=chilla,color="brown",ci=None)
plt.title("Urban vs Rural Population of Pakistan")

#style
sns.set_style(style=None, rc=None)
sns.set_style("white")

#limits x and y
#plt.xlim(0)
#plt.ylim(0)
x:("Number")




plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
